# %%
from xgboost import XGBClassifier



xgb_model = XGBClassifier(n_estimators=1000, learning_rate=0.03, max_depth=6, subsample=0.8, n_thread = -1)
xgb_model.fit(xtrain,ytrain)
y_pred = xgb_model.predict(xtest)

xgb_score = f1_score(ytest,y_pred)

xgb_score
# Out:
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [08:41:27] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "n_thread" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# 0.5377821393523062

# %%
train_tdf = tdif[:31962,:]
test_tdf = tdif[31962,:]

xtrain_tdf = train_tdf[ytrain.index]
xtest_tdf = train_tdf[ytest.index]



xgb_model.fit(xtrain_tdf,ytrain)
y_pred = xgb_model.predict(xtest_tdf)

xgb_score = f1_score(ytest,y_pred)

xgb_score
# Out:
# 0.5416666666666666

# %%
train_w2v = word_vec_df.iloc[:31962,:]
test_w2v = word_vec_df.iloc[31962:,:]

xtrain_w2v = train_w2v.iloc[ytrain.index]
xtest_w2v = train_w2v.iloc[ytest.index]


xgb_model.fit(xtrain_w2v,ytrain)
y_pred = xgb_model.predict(xtest_w2v)

w2v_score = f1_score(ytest,y_pred)

w2v_score
# Out:
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:200: UserWarning: [08:41:48] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "n_thread" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# 0.6402164111812444

# %%
xtrain_d2v = doc_vec_df.iloc[ytrain.index]
xtest_d2v = doc_vec_df.iloc[ytest.index]



xgb_model.fit(xtrain_d2v,ytrain)
y_pred = xgb_model.predict(xtest_d2v)

d2v_score = f1_score(ytest,y_pred)

d2v_score
# Out:
# 0.3638320775026911
